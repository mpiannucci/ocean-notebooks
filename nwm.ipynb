# %%
import xarray as xr

ds = xr.open_dataset(
    "reference://", engine="zarr", backend_kwargs={"consolidated": True, "storage_options": {
        "fo": "s3://nextgen-dmac-cloud-ingest/nwm/short_range/nwm.short_range.channel_rt.conus.best.zarr",
        "remote_protocol": "s3",
        "remote_options": {
            "anon": True,
        },
        "target_protocol": "s3",
        "target_options": {
            "anon": True,
        }
    }},
)

ds
# Out:
# /Users/matthew.iannucci/Developer/ocean-notebooks/venv/lib/python3.10/site-packages/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Developer/ocean-notebooks/venv/lib/python3.10/site-packages/fsspec/implementations/reference.py:734, in ReferenceFileSystem._cat_common(self, path, start, end)
#     733 try:
# --> 734     part = self.references[path]
#     735 except KeyError:
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Developer/ocean-notebooks/venv/lib/python3.10/site-packages/fsspec/mapping.py:151, in FSMap.__getitem__(self, key, default)
# ...
