# %%
import cf_xarray
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

ds = xr.open_dataset('rtofs_glo_3dz_f180_6hrly_hvr_US_east.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (MT: 1, Depth: 40, Y: 1710, X: 742)
# Coordinates:
#   * MT           (MT) datetime64[ns] 2023-09-27T12:00:00
#     Date         (MT) float64 ...
#   * Depth        (Depth) float32 0.0 2.0 4.0 6.0 ... 2.5e+03 3e+03 4e+03 5e+03
#   * Y            (Y) int32 1 2 3 4 5 6 7 ... 1704 1705 1706 1707 1708 1709 1710
#   * X            (X) int32 1 2 3 4 5 6 7 8 9 ... 735 736 737 738 739 740 741 742
#     Latitude     (Y, X) float32 ...
#     Longitude    (Y, X) float32 ...
# Data variables:
#     u            (MT, Depth, Y, X) float32 ...
#     v            (MT, Depth, Y, X) float32 ...
#     temperature  (MT, Depth, Y, X) float32 ...
#     salinity     (MT, Depth, Y, X) float32 ...
# Attributes:
#     Conventions:  CF-1.0
#     title:        HYCOM ATLb2.00
#     institution:  National Centers for Environmental Prediction
#     source:       HYCOM archive file
#     experiment:   92.8
#     history:      archv2ncdf3z

# %%
ds.temperature.cf.isel(time=0, vertical=0).plot()

# %%
sst = ds.temperature.cf.sel(Depth=0, method='nearest')
sst.cf.plot(x='longitude', y='latitude')
